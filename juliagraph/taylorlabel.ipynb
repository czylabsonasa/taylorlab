# %%
include("main.jl")
# Out:
# nodes, edges: (18771, 198050)
# olvas: 0.241 sec
# num. of labels: 18771
# inilabel: 0.04 sec
# ties/changes:
# WARNING: replacing module utils.
# WARNING: replacing module label.
# WARNING: replacing module rajz.
# 7631/37243=0.20489756464302017
# labelprop: 4.113 sec
# labels left:1057
# postlab: 0.022 sec
# innerdeg: 0.024 sec
# rajz: 0.01 sec
# osszes: 4.453 sec

# %% [markdown]
# ### A [Zachary karate-klub](http://konect.uni-koblenz.de/networks/ucidata-zachary) gráfja, felbontva:
# ![](ucidata-zachary.png)

# %%
plot(log.(x),log.(y),seriestype=:scatter,markersize=3,legend=false,show=true)
